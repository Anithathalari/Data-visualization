# %%
import pandas as pd
mall = pd.read_csv(r"C:\Users\T.anitha\Downloads\Mall_Customers.csv")
mall
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# # LINE CHART

# %%
mall['Annual Income (k$)'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # scatter chart

# %%
mall.plot(kind = 'scatter',x = 'mallAnnual Income (k$)',y = 'Spending Score (1-100)')
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
mall['Annual Income (k$)'].corr(mall['Spending Score (1-100)'])
# Out:
# 0.009902848094037608

# %%
mall.plot(kind = 'scatter',x = 'Age',y = 'Spending Score (1-100)')
# Out:
# <Axes: xlabel='Age', ylabel='Spending Score (1-100)'>

# %%
mall['Age'].corr(mall['Spending Score (1-100)'])
# Out:
# -0.32722684603909014

# %% [markdown]
# mall.plot(kind = 'scatter',x = 'Age',y = 'Annual Income (k$)')

# %%
mall['Age'].corr(mall['Annual Income (k$)'])
# Out:
# -0.012398042736060145

# %% [markdown]
# # histogram

# %%
mall['Age'].plot(kind = 'hist',bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
mall[['Age','Spending Score (1-100)']].plot(kind = 'hist',bins = 10,alpha = 0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # bar and barh chart

# %%
mall['Gender'].value_counts()
# Out:
# Gender
# Female    112
# Male       88
# Name: count, dtype: int64

# %%
totals = round(mall.groupby('Gender')['Annual Income (k$)'].mean(),2)
totals
totals.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
totals = mall.groupby(['Gender'])['Annual Income (k$)'].mean().sort_values()
totals. plot(kind = 'bar',alpha = 0.6)
# Out:
# <Axes: xlabel='Gender'>

# %%
r_totals = mall.groupby(['Gender'])[['Annual Income (k$)','Spending Score (1-100)']].mean()
r_totals. plot(kind = 'bar',alpha = 0.6,stacked = True)
# Out:
# <Axes: xlabel='Gender'>

# %%
totals. plot(kind = 'barh',alpha = 0.6,stacked = True)
# Out:
# <Axes: ylabel='Gender'>

# %% [markdown]
# # pie chart

# %%
r_totals
# Out:
#         Annual Income (k$)  Spending Score (1-100)
# Gender
# Female           59.250000               51.526786
# Male             62.227273               48.511364

# %%
r_totals.plot(kind = 'pie',subplots= True)
# Out:
# array([<Axes: ylabel='Annual Income (k$)'>,
#        <Axes: ylabel='Spending Score (1-100)'>], dtype=object)

# %%
r_totals.plot.bar(color = ['green','red'],subplots = True,rot = 45)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 r_totals.plot.bar(color = ['green','red'],subplots = True,rot = 45)
#
# NameError: name 'r_totals' is not defined

# %% [markdown]
# # box plot

# %%
mall['Annual Income (k$)'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
mall[['Gender','Annual Income (k$)']].plot.box()
# Out:
# <Axes: >

# %%
import numpy as np
q2 =np.quantile(mall['Annual Income (k$)'],0.5)
q2
# Out:
# 61.5

# %%
q1 =np.quantile(mall['Annual Income (k$)'],0.25)
q1
# Out:
# 41.5

# %%
q3 =np.quantile(mall['Annual Income (k$)'],0.75)
q3
# Out:
# 78.0

# %%
iqr = (q3-q1)
iqr
# Out:
# 36.5

# %%
[q3-1.5*iqr,q1+1.5*iqr]
min,max =[q3-1.5*iqr,q1+1.5*iqr]
iqrrange = [min,max]
iqrrange
# Out:
# [23.25, 96.25]

# %%
annual_range = mall[(mall['Annual Income (k$)'] >= min) &(mall['Annual Income (k$)']<= max)]
annual_range.count()
# Out:
# CustomerID                160
# Gender                    160
# Age                       160
# Annual Income (k$)        160
# Spending Score (1-100)    160
# dtype: int64

# %%
annual_range['Annual Income (k$)'].plot(kind = 'box',vert = False)
# Out:
# <Axes: >

# %%
annual_range[['Age','Spending Score (1-100)']].plot(kind = 'box')
# Out:
# <Axes: >

# %%
#annual_range['Gender'].plot(kind = 'box')

# %% [markdown]
# # area plot

# %%
mall[['Annual Income (k$)','Spending Score (1-100)']].plot(kind = 'area',alpha = 0.3)
# Out:
# <Axes: >

# %% [markdown]
# # KDE plot

# %%
mall[['Annual Income (k$)','Spending Score (1-100)']].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # hexabin plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

mall = pd.read_csv(r"C:\Users\T.anitha\Downloads\Mall_Customers.csv")
mall.plot(kind = 'hexbin',x = 'Age',y = 'Annual Income (k$)')
plt.show()

# %%
mall.plot(kind = 'hexbin',x = 'Age',y = 'Annual Income (k$)',gridsize = 10,figsize = (7,5))
plt.show()

# %%
mall.plot(kind = 'scatter',x = 'Age',y = 'Annual Income (k$)',figsize = (8,7),
        title = 'age and annual income' ,ylabel = 'annual income of customer',xlabel = 'age',marker = 'D',color = 'magenta');

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(mall,alpha = 1,figsize = (10,6),diagonal = 'kde');

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(mall,alpha = 1,figsize = (10,6));
